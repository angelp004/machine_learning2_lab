# %% [markdown]
# <a href="https://colab.research.google.com/github/angelp004/machine_learning2_lab/blob/main/finds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataset based on the image
data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'Yes'],
    ['Rainy', 'Worm', 'High', 'Strong', 'Warm', 'Change', 'No'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'Yes'],
    ['Rainy','Cold', 'Warm', 'Strong', 'Warm', 'Change', 'No']
]

def find_s(data):
    # Initialize hypothesis to the first positive example
    hypothesis = None
    for row in data:
        if row[-1].lower() == 'yes':
            hypothesis = row[:-1]
            break

    # Update hypothesis by comparing with each positive example
    for row in data:
        if row[-1].lower() == 'yes':
            for i in range(len(hypothesis)):
                if hypothesis[i] != row[i]:
                    hypothesis[i] = '?'

    return hypothesis

hypothesis = find_s(data)
print(hypothesis)  # This will print only the final hypothesis list
# Out:
# ['Sunny', 'Warm', '?', 'Strong', '?', '?']
